# %% [markdown]
# Mount google drive

# %%
# run once when you start the Google Colabratory session
# mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 01

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/GCIP/"
# !python3 checksum.py
# Out:
# /content/drive/MyDrive/Colab Notebooks/GCIP
# Enter your ID: abcv
#
# Your code: 156

# %% [markdown]
# 02

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/GCIP/02/"
# !python3 boxfilter.py input.png boxfilter.png
# Out:
# /content/drive/MyDrive/Colab Notebooks/GCIP/02

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/GCIP/02/"
# !python3 gaussianfilter.py input.png gaussianfilter.png
# Out:
# /content/drive/MyDrive/Colab Notebooks/GCIP/02

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/GCIP/02/"
# !python3 sobelXfilter.py input.png sobelXfilter.png
# Out:
# /content/drive/MyDrive/Colab Notebooks/GCIP/02

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/GCIP/02/"
# !python3 sobelYfilter.py input.png sobelYfilter.png
# Out:
# /content/drive/MyDrive/Colab Notebooks/GCIP/02

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/GCIP/02/"
# !python3 laplacianfilter.py input.png laplacianfilter.png
# Out:
# /content/drive/MyDrive/Colab Notebooks/GCIP/02
# (480, 640, 3)

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/GCIP/02/"
# !python3 DoGfilter.py input.png DoGfilter.png
# Out:
# /content/drive/MyDrive/Colab Notebooks/GCIP/02

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/GCIP/02/"
# !python3 UnsharpMask.py input.png UnsharpMask.png
# Out:
# /content/drive/MyDrive/Colab Notebooks/GCIP/02

# %% [markdown]
# 03

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/GCIP/03/"
# !python3 LinearTrans.py input.png LinearTrans.png
# Out:
# /content/drive/MyDrive/Colab Notebooks/GCIP/03

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/GCIP/03/"
# !python3 Gamma.py input.png Gamma.png
# Out:
# /content/drive/MyDrive/Colab Notebooks/GCIP/03

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/GCIP/03/"
# !python3 HSV.py input.png HSV.png
# Out:
# /content/drive/MyDrive/Colab Notebooks/GCIP/03

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/GCIP/03/"
# !python3 YCbCr.py input.png YCbCr.png
# Out:
# /content/drive/MyDrive/Colab Notebooks/GCIP/03

# %% [markdown]
# 04

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/GCIP/04/"
# !python3 sample1.py sample1.png output1.png
# Out:
# /content/drive/MyDrive/Colab Notebooks/GCIP/04

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/GCIP/04/"
# !python3 sample2.py sample2.png output2.png
# Out:
# /content/drive/MyDrive/Colab Notebooks/GCIP/04

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/GCIP/04/"
# !python3 sample3.py sample3.png output3.png
# Out:
# /content/drive/MyDrive/Colab Notebooks/GCIP/04

# %% [markdown]
# 05

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/GCIP/05/"
# !python3 Homography.py input.png output.png
# Out:
# /content/drive/MyDrive/Colab Notebooks/GCIP/05

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/GCIP/05/"
# !python3 Composition.py input.png output.png
# Out:
# /content/drive/MyDrive/Colab Notebooks/GCIP/05

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/GCIP/05/"
# !python3 Warp.py example1.png output.png
# Out:
# /content/drive/MyDrive/Colab Notebooks/GCIP/05
# [[ 1.1602440e+00 -6.7045212e-02 -1.5914648e+02]
#  [ 1.2566566e-01  1.5844879e+00 -4.5337500e+02]
#  [-1.2172945e-04  6.3822418e-04  1.0000000e+00]]

# %% [markdown]
# 06

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/GCIP/06/"
# !python3 TemplateMaching.py image.png template.png
# Out:
# /content/drive/MyDrive/Colab Notebooks/GCIP/06

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/GCIP/06/"
# !python3 FeatureMatching.py Query.png Input1.png output1.png
# Out:
# /content/drive/MyDrive/Colab Notebooks/GCIP/06

# %% [markdown]
# 08

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/GCIP/08/"
# !python3 FaceDetection.py family.png output.png
# Out:
# /content/drive/MyDrive/Colab Notebooks/GCIP/08

# %% [markdown]
# 09

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/GCIP/09/"
# !python3 BackgroundSub.py B00.png B01.png output01.png
# Out:
# /content/drive/MyDrive/Colab Notebooks/GCIP/09

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/GCIP/09/"
# !python3 FrameSub.py B03.png B04.png B05.png output345.png
# Out:
# /content/drive/MyDrive/Colab Notebooks/GCIP/09

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/GCIP/09/"
# !python3 OpticalFlow.py F00.png F01.png output01.png
# Out:
# /content/drive/MyDrive/Colab Notebooks/GCIP/09

# %% [markdown]
# 10

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/GCIP/10/"
# !python3 AND.py
# Out:
# /content/drive/MyDrive/Colab Notebooks/GCIP/10
# NG: (+1,+1) -> +0 [+1]
# NG: (+1,-1) -> +0 [-1]
# NG: (-1,+1) -> +0 [-1]
# NG: (-1,-1) -> +0 [-1]

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/GCIP/10/"
# !python3 OR.py
# Out:
# /content/drive/MyDrive/Colab Notebooks/GCIP/10
# NG: (+1,+1) -> +0 [+1]
# NG: (+1,-1) -> +0 [+1]
# NG: (-1,+1) -> +0 [+1]
# NG: (-1,-1) -> +0 [-1]

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/GCIP/10/"
# !python3 MIN.py
# Out:
# /content/drive/MyDrive/Colab Notebooks/GCIP/10
# x: [[0.80663927 0.07751456 0.43900144]]
# y: [[0 0 0]]
# z: [[0 0 0]]
# c: [[-1  1 -1]]
# NG

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/GCIP/10/"
# !python3 MAX.py
# Out:
# /content/drive/MyDrive/Colab Notebooks/GCIP/10
# x: [[0.71722616 0.78804937 0.61312441]]
# y: [[0 0 0]]
# z: [[0 0 0]]
# c: [[-1  1 -1]]
# NG
